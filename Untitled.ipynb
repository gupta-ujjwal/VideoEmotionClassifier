# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
import random
import cv2

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('Dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('Dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 100 images belonging to 2 classes.
# Found 19 images belonging to 2 classes.

# %%
for X_batch, y_batch in train_datagen.flow_from_directory('Dataset/training_set', batch_size=50, save_format='png'):
    # create a grid of 2x2 images
    for i in range(0, 4):
        plt.subplot(220 + 1 + i)
        plt.imshow(X_batch[i], cmap=plt.get_cmap('gray'))
    # show the plot
    plt.show()
    break
# Out:
# Found 100 images belonging to 2 classes.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Convolution2D(16, 3, 3, input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Convolution2D(64, 3, 3, activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(output_dim = 128, activation = 'relu'))
# classifier.add(Dropout(0.2))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), input_shape=(64, 64, 3..., activation="relu")`
#   """
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   # This is added back by InteractiveShellApp.init_path()
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`

# %%
classifier.fit_generator(training_set,
                         samples_per_epoch = 50,
                         nb_epoch = 100,
                         validation_data = test_set,
                         nb_val_samples = 50,
                         verbose=1, callbacks=[es]
                        )
# Out:
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# /home/ujjwalgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=<keras_pre..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=1, epochs=100, validation_steps=50)`
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6995 - acc: 0.5938 - val_loss: 0.6983 - val_acc: 0.4737
# Epoch 2/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6988 - acc: 0.5312 - val_loss: 0.9166 - val_acc: 0.5263
# Epoch 3/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9829 - acc: 0.4688 - val_loss: 0.7408 - val_acc: 0.5789
# Epoch 4/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4321 - acc: 0.7500 - val_loss: 0.7495 - val_acc: 0.5789
# Epoch 5/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6631 - acc: 0.5938 - val_loss: 0.7076 - val_acc: 0.6316
# Epoch 6/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.6733 - acc: 0.6562 - val_loss: 0.6835 - val_acc: 0.5263
# Epoch 7/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7029 - acc: 0.5938 - val_loss: 0.7002 - val_acc: 0.4737
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.5558 - acc: 1.0000 - val_loss: 0.7357 - val_acc: 0.5263
# Epoch 9/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5707 - acc: 0.7500 - val_loss: 0.7724 - val_acc: 0.5789
# Epoch 10/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6382 - acc: 0.5312 - val_loss: 0.7533 - val_acc: 0.4737
# Epoch 11/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6764 - acc: 0.5625 - val_loss: 0.7106 - val_acc: 0.5789
# Epoch 12/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8347 - acc: 0.5000 - val_loss: 0.6908 - val_acc: 0.5263
# Epoch 13/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6336 - acc: 0.6562 - val_loss: 0.6954 - val_acc: 0.5263
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.6004 - acc: 0.6250 - val_loss: 0.6994 - val_acc: 0.5789
# Epoch 15/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5635 - acc: 0.7188 - val_loss: 0.6978 - val_acc: 0.5789
# Epoch 16/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.
100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3557 - acc: 0.8750 - val_loss: 0.5871 - val_acc: 0.6842
# Epoch 47/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4434 - acc: 0.8125 - val_loss: 0.5947 - val_acc: 0.6842
# Epoch 48/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3031 - acc: 0.7500 - val_loss: 0.5932 - val_acc: 0.6842
# Epoch 49/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5071 - acc: 0.7188 - val_loss: 0.5858 - val_acc: 0.6316
# Epoch 50/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3319 - acc: 0.8750 - val_loss: 0.5916 - val_acc: 0.6316
# Epoch 51/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4679 - acc: 0.8750 - val_loss: 0.5898 - val_acc: 0.6842
# Epoch 52/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5507 - acc: 0.7500 - val_loss: 0.6158 - val_acc: 0.6316
# Epoch 53/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4952 - acc: 0.6875 - val_loss: 0.6382 - val_acc: 0.7368
# Epoch 54/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4858 - acc: 0.7500 - val_loss: 0.6491 - val_acc: 0.6842
# Epoch 55/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3140 - acc: 0.8438 - val_loss: 0.6684 - val_acc: 0.6842
# Epoch 56/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2994 - acc: 1.0000 - val_loss: 0.7508 - val_acc: 0.6316
# Epoch 57/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5317 - acc: 0.6875 - val_loss: 0.7909 - val_acc: 0.6316
# Epoch 58/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4496 - acc: 0.7500 - val_loss: 0.8017 - val_acc: 0.6316
# Epoch 59/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4157 - acc: 0.7812 - val_loss: 0.7505 - val_acc: 0.6316
# Epoch 60/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6379 - acc: 0.5000 - val_loss: 0.6238 - val_acc: 0.6842
# Epoch 61/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3597 - acc: 0.8125 - val_loss: 0.6153 - val_acc: 0.6842
# Epoch 62/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4388 - acc: 0.7500 - val_loss: 0.6795 - val_acc: 0.6842
# Epoch 63/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4069 - acc: 0.8438 - val_loss: 0.7080 - val_acc: 0.6316
# Epoch 64/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4175 - acc: 0.7500 - val_loss: 0.6639 - val_acc: 0.6842
# Epoch 65/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3867 - acc: 0.8438 - val_loss: 0.6178 - val_acc: 0.6842
# Epoch 66/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3718 - acc: 0.9062 - val_loss: 0.6138 - val_acc: 0.6842
# Epoch 67/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3886 - acc: 0.7812 - val_loss: 0.6372 - val_acc: 0.7368
# Epoch 68/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3837 - acc: 0.7500 - val_loss: 0.6843 - val_acc: 0.6842
# Epoch 69/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3930 - acc: 0.7812 - val_loss: 0.7410 - val_acc: 0.6842
# Epoch 70/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3984 - acc: 0.7812 - val_loss: 0.7615 - val_acc: 0.6842
# Epoch 71/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3846 - acc: 0.8125 - val_loss: 0.7442 - val_acc: 0.6842
# Epoch 72/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5973 - acc: 0.7500 - val_loss: 0.6777 - val_acc: 0.6842
# Epoch 00072: early stopping

# %%
image = cv2.imread('test3.jpg')
orig = image.copy()
image = cv2.resize(image, (64,64))#resize image maintaining aspect ratio

# %%
import numpy as np
from keras.preprocessing.image import img_to_array
image = image.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
res = classifier.predict(image)[0]

# %%
res
# Out:
# array([0.53405595], dtype=float32)
